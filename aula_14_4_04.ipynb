# %% [markdown]
# <a href="https://colab.research.google.com/github/laffaet08/input_aula/blob/main/aula_14_4_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input( "digite o seu nome: ")
print ("seu nome é:", nome)
# Out:
# digite o seu nome: kmk
# seu nome é: kmk

# %% [markdown]
# atividade01_

# %%
valor1 = int(input("digite o valor: "))
valor2 = int(input("digite o valor: "))
resultado = valor1 + valor2
print(resultado)
# Out:
# digite o valor: 5
# digite o valor: 8
# 13

# %% [markdown]
# atividade02_

# %%
valor1 = int(input("digite o valor: "))
valor2 = int(input("digite o valor: "))
resultado = valor1 - valor2
print(resultado)

# %% [markdown]
# atv003_

# %%
from builtins import print

valor1 = int(input("digite o valor: "))
valor2 = int(input("digite o valor: "))
soma = valor1 + valor2
subtracao = valor1 - valor2
multiplicacao = valor1 * valor2
divisao = valor1 / valor2
print(soma, subtracao, multiplicacao, divisao)
# Out:
# digite o valor: 30
# digite o valor: 2
# 32 28 60 15.0

# %%
usuario = input("digite seu nome de usuario:")
print("ola", usuario, "seja bem vindo!")
# Out:
# digite seu nome de usuario:llaffaet
# ola llaffaet seja bem vindo!
